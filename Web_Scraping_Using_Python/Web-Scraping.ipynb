# %% [markdown]
# ## web scraping first project
# ### Collecting product from draze.pk

# %%
# importing 
import requests
from bs4 import BeautifulSoup
import json

for_search = 'books' # product type to search on Draze
from_page = 2 # page on Draze

def soup_content(search, page_no):
    URL = f'https://www.daraz.pk/catalog/?page={page_no}&q={search}'
    print(URL)

    respo = requests.get(URL) # doing request fro URL assining responce to respo
    soup = BeautifulSoup(respo.content, 'html.parser') # using BeautifulSoup to make it useable
    return soup
soup = soup_content(for_search, from_page) # soup is content can be use
# Out:
# https://www.daraz.pk/catalog/?page=2&q=books

# %%
sope_script3 = str(soup.findAll('script')[3]) # converting sope third script to str

itemlists = sope_script3[sope_script3.find('listItems')+len('listItems:[')+1:sope_script3.find('sortItems')] # faching only products as itemlist
itemlist = itemlists.replace('"', '').split(',') # removing and replacing 

prod = []
products = []

for i in itemlist:
    if 'name:' in i:
        name = i.replace('{name:', '')
        prod.append(name)
    if 'productUrl' in i and 'www.daraz.pk' in i:
        proURL = i.replace('productUrl:', '')
        prod.append(proURL)
    if 'ratingScore' in i:
        rating = i.replace('ratingScore:', '')
        prod.append(rating)
    if 'current_price' in i:
        price = i.replace('current_price:', '')
        prod.append(int(float(price)))
    if len(prod)==4:
        products.append(prod)
        prod = []
import pandas as pd

df = pd.DataFrame(products, columns=['Name', 'Price', 'Link', 'Rating'])
df.Rating = df.Rating.astype('float64').round(2)
df
# Out:
#                                                  Name  Price  \
# 0                                            Rich Dad    295
# 1   OETP A Guide Book For NUST Entry Test 3rd Edit...   1200
# 2                        Textbook of Biology Grade 11    400
# 3   Jannat Kay Pattay Urdu novel by Nemra nimra Ah...    599
# 4                        Textbook of Biology Grade 12    350
# 5              Good to Great Book by James C. Collins    295
# 6                     Business Administration For CSS    650
# 7     Shayad By Jon Elia in urdu Poetry Original Book    499
# 8                      PMC NMDCAT NUMS-AGHA Khan 2021   2200
# 9   Chemical Grammar by Salman ul Waheed (6th Edit...    850
# 10  The Monk Who Sold His Ferr@ri: A Fable About F...    295
# 11  Horticulture by National Book Foundation by Ma...    550
# 12                           Deep Work by Cal Newport    295
# 13                     Textbook of Chemistry Grade 12    370
# 14  Peer E Kamil (SAW) Novel By Umera Ahmed Best s...    499
# 15                  Atomic Habits Book by James Clear    295
# 16                      Dogar ISSB Success Test Guide   1000
# 17  How to Win Friends and Influence People Book b...    295
# 18  Qualify Guide for Headmaster / Headmistress fo...   1000
# 19                              Basics of Agriculture    700
# 20  Latest Advanced PPSC Model Papers MCQs Book by...   1550
# 21  General Science and Ability with MCQs by Jahan...    999
# 22  State Bank of Pakistan GET FS Test Guide For O...    650
# 23  Vertex Islamiat Intermediate Part 1 With All B...    250
# 24                      Rule by Fear By Ammar Ali Jan    770
# 25  Organic Spectroscopy and Chromatography by M.Y...    350
# 26  Namal - ??? Urdu novel by Nemra Ahmed Nimra Ah...    999
# 27         Reflections Of A Man II Book by Amari Soul    295
# 28           The Psychology of Money by Morgan Housel    295
# 29                       Oxford Reading Circle Book 3    430
# 30  Radiography & Medical Imaging Solved papers 20...    250
# 31        The Art of Public Speaking by Dale Carnegie    320
