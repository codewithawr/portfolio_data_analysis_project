# %%
#This will not run on online IDE
import requests
from bs4 import BeautifulSoup
import json

for_search = 'books'

URL = f"https://www.daraz.pk/catalog/?q={for_search}"
r = requests.get(URL)

soup = BeautifulSoup(r.content, 'html.parser') # If this line causes an error, run 'pip install html5lib' or install html5lib
# print(soup.prettify())
# json.loads(u)

itemlists = str(soup.findAll('script')[3])[str(soup.findAll('script')[3]).find('listItems')-1:str(soup.findAll('script')[3]).find('sortItems')]

# %%
itemlist = itemlists.replace('"', '').replace('listItems:[', '').split(',')

prod = []
products = []

for i in itemlist:
    if 'name:' in i:
        name = i.replace('{name:', '')
        prod.append(name)
    if 'productUrl' in i and 'www.daraz.pk' in i:
        proURL = i.replace('productUrl:', '')
        prod.append(proURL)
    if 'ratingScore' in i:
        rating = i.replace('ratingScore:', '')
        prod.append(rating)
    if 'current_price' in i:
        price = i.replace('current_price:', '')
        prod.append(price)
    # if 'image' in i:
    #     image = i.replace('image:', '')
    #     prod.append(image)
    if len(prod)==4:
        products.append(prod)
        # print(prod)
        prod = []
    # print(name, proURL, rating, price)
# products
import pandas as pd

df = pd.DataFrame(products)
df
# Out:
#                                                     0        1  \
# 0          PHARMACOLOGICAL CLASSIFICATION  (CHART) 3e   145.00
# 1   Master Your English – 222 Rules of Grammar | E...   199.00
# 2                                            Rich Dad   270.00
# 3   OETP A Guide Book For NUST Entry Test 3rd Edit...  1200.00
# 4   Chemical Grammar by Salman ul Waheed (6th Edit...   850.00
# 5                        Textbook of Biology Grade 12   350.00
# 6                        Textbook of Biology Grade 11   400.00
# 7   Namal - ??? Urdu novel by Nemra Ahmed Nimra Ah...   949.00
# 8                      Textbook of Chemistry Grade 12   370.00
# 9   Peer E Kamil (SAW) Novel By Umera Ahmed Best s...   499.00
# 10  Horticulture by National Book Foundation by Ma...   550.00
# 11                  Atomic Habits Book by James Clear   270.00
# 12  Qualify Guide for Headmaster / Headmistress fo...  1000.00
# 13                    Dogar NUST NET Business Studies  1200.00
# 14  Influence: The Psychology of Persuasion by Rob...   270.00
# 15  Jannat Kay Pattay Urdu novel by Nemra nimra Ah...   499.00
# 16  Urdu Adab ki Mukhtasar Tareen Tareekh by Dr Sa...  1800.00
# 17  Organic Spectroscopy and Chromatography by M.Y...   350.00
# 18    Shayad By Jon Elia in urdu Poetry Original Book   499.00
# 19      Yani By Jon Elia in urdu Poetry Original Book   429.00
# 20  Text Book of Biological Techniques For BS and ...   350.00
# 21                     PMC NMDCAT NUMS-AGHA Khan 2021  2200.00
# 22  How to Win Friends and Influence People Book b...   270.00
# 23                    Business Administration For CSS   650.00
# 24  La Hasil Novel By Umaira Ahmad Pakistan's Best...   239.00
# 25           The Psychology of Money by Morgan Housel   270.00
# 26  Latest Advanced PPSC Model Papers MCQs Book by...  1550.00
# 27             Good to Great Book by James C. Collins   270.00
# 28  The Obstacle Is the Way: The Timeless Art of T...   270.00
# 29        The Al Chemist by Paulo Coelho Urdu Edition   300.00
# 30                           Deep Work by Cal Newport   270.00
# 31  OETP A Guide Book For NUST Entry Test With Pas...  1250.00
# 32  Vertex Islamiat Intermediate Part 1 With All B...   250.00
